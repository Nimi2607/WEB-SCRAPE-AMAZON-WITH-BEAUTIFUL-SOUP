# %% [markdown]
# <a href="https://colab.research.google.com/github/Nimi2607/WEB-SCRAPE-AMAZON-WITH-BEAUTIFUL-SOUP/blob/main/WEB_SCRAPE_AMAZON_WITH_BEAUTIFUL_SOUP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **WEB SCRAPE AMAZON WITH BEAUTIFUL SOUP**

# %% [markdown]
# In this project i have build a Python program that "web scrapes" Amazon product information using a library called **Beautiful Soup**.

# %% [markdown]
# Web scraping is the process of extracting data from a website. This data is collected and then exported in a way that the user will find more valuable, such as a CSV file. Manual web scraping is possible, but automated methods are typically preferred since they can be less expensive and faster.

# %% [markdown]
# Import the libraries

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# In Python, we can use the Beautiful Soup library to extract data from HTML and XML files. With the help of parsers like lxml, we can navigate, search, and modify the parse tree.

# %% [markdown]
#  When we send an HTTP request, we send some headers along with the request.Define them in a dictionary called headers.

# %%
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
  'Accept-Language': 'en-US,en;q=0.5'
}

# %% [markdown]
# Next, we will define a function get_product_details().

# %%
def get_product_details(product_url: str) -> dict:
  pass

# %% [markdown]
# The function will accept a string parameter, product_url and returns a dictionary. Let's name this dictionary product_details.

# %%
def get_product_details(product_url: str) -> dict:
  # Create an empty product details dictionary
  product_details = {}

# %% [markdown]
# Now, let's make an HTTP request to get the HTML content of the product page. Using the BeautifulSoup class, I will create a soup of the page content.

# %%
def get_product_details(product_url: str) -> dict:
  # Create an empty product details dictionary
  product_details = {}

  # Get the product page content and create a soup
  page = requests.get(product_url, headers=headers)
  soup = BeautifulSoup(page.content, features='lxml')
  title = soup.find('span', attrs={'id': 'productTitle'}).get_text().strip()
  price = soup.find('span', attrs={'class': 'a-price'}).get_text().strip()

# %% [markdown]
# Now comes the most important part of the tutorial where I will extract data from the page. For the sake of this tutorial, I will extract two data:
#
#
# *   Title of the product
# *   Price of the product

# %% [markdown]
# The title is wrapped with a span tag with an attribute id productTitle. Let's use this id to extract the title of the product.

# %% [markdown]
# ![Image 12-01-25 at 12.59 AM.JPG](data:image/jpeg;base64,...)

# %%
def get_product_details(product_url: str) -> dict:
  # Create an empty product details dictionary
  product_details = {}

  # Get the product page content and create a soup
  page = requests.get(product_url, headers=headers)
  soup = BeautifulSoup(page.content, features='lxml')
  title = soup.find('span', attrs={'id': 'productTitle'}).get_text().strip()
  price = soup.find('span', attrs={'class': 'a-price'}).get_text().strip()
  extracted_price = soup.find('span', attrs={'class': 'a-price'}).get_text().strip()
  price = '$' + extracted_price.split('$')[1]
  # Adding it to the product details dictionary
  product_details['title'] = title
  product_details['price'] = price
